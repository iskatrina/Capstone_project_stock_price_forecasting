# %% [markdown]
# ## Goal: to add Technical features to the choosen stocks  based on Clustering Analysis

# %%
import pickle
import ta
import pandas as pd
import os
import numpy as np

# %%
def add_features(df):

    windows = [6,18,24,30,50,100,200]

    all_tickers = []

    for ticker, df0 in df.groupby('ticker'):
        df0 = df0.copy()

        for w in windows:
            if len(df0) >= w:
                # RSI
                df0['RSI_' + str(w)] = ta.momentum.RSIIndicator(df0['Close'], window=w, fillna=True).rsi()


                # MACD
                for w2 in windows:
                    if w > w2:
                        # Will utilize macd_diff because that is more normalized
                        df0['MACD_f'+str(w2)+'_s'+str(w)] = ta.trend.MACD(df0['Close'], window_slow=w2, window_fast=w, fillna=True).macd_diff()

                # Bollinger Bands
                ## Stdev default=2, but can change it if desired
                # Currently returning high/low band indicators, but can add actual values if desired.
                bbands = ta.volatility.BollingerBands(df0['Close'], window=w, fillna=True)
                df0['BBands_' + str(w) + '_h_ind'] = bbands.bollinger_hband_indicator()
                df0['BBands_' + str(w) + '_l_ind'] = bbands.bollinger_lband_indicator()
                #actual values
                df0['BBands_' + str(w) + 'hband'] = bbands.bollinger_hband()
                df0['BBands_' + str(w) + 'lband'] = bbands.bollinger_lband()

                # Average True Range (ATR)
                df0['ATR_' + str(w)] = ta.volatility.AverageTrueRange(high=df0['High'],low=df0['Low'],close=df0['Close'], window=w, fillna=True).average_true_range()
                
                # Donchian Channel (DONCHIAN)
                d_channel = ta.volatility.DonchianChannel(high=df0['High'],low=df0['Low'],close=df0['Close'], window=w, fillna=True)
                df0['DONCHAIN_' + str(w) + 'hband'] = d_channel.donchian_channel_hband()
                df0['DONCHAIN_' + str(w) + 'lband'] = d_channel.donchian_channel_lband()
                
                # Keltner Channel (KELTNER)
                # Using SMA as centerline
                k_channel = ta.volatility.KeltnerChannel(high=df0['High'],low=df0['Low'],close=df0['Close'], window=w, 
                                                      original_version= True, fillna=True)
                df0['KELTNER_' + str(w) + '_h_ind'] = k_channel.keltner_channel_hband_indicator()
                df0['KELTNER_' + str(w) + '_l_ind'] = k_channel.keltner_channel_lband_indicator()
                
                # Stochastic Oscillator (SR/STOCH)
                df0['STOCH_' + str(w)] = ta.momentum.StochasticOscillator(high=df0['High'],low=df0['Low'],close=df0['Close'], window=w, fillna=True).stoch()

                # Chaikin Money Flow Indicator (CMF)
                df0['CMF_' + str(w)] = ta.volume.ChaikinMoneyFlowIndicator(high=df0['High'],low=df0['Low'],close=df0['Close'],volume=df0['Volume'], window=w, fillna=True).chaikin_money_flow()

                # Ichimoku Indicator (ICHI)
                for w2 in windows:
                    for w3 in windows:
                        if (w > w2) & (w2 > w3):
                            ichimoku = ta.trend.IchimokuIndicator(high=df0['High'],low=df0['Low'],window1=w3, window2=w2, window3=w, fillna=True)
                            df0['ICHI_conv_' + str(w3)+'_'+str(w2)+'_'+str(w)] = ichimoku.ichimoku_conversion_line()
                            df0['ICHI_base_' + str(w3)+'_'+str(w2)+'_'+str(w)] = ichimoku.ichimoku_base_line()
                            df0['ICHI_diff_' + str(w3)+'_'+str(w2)+'_'+str(w)] = df0['ICHI_conv_' + str(w3)+'_'+str(w2)+'_'+str(w)] - df0['ICHI_base_' + str(w3)+'_'+str(w2)+'_'+str(w)]


                # SMA
                df0['SMA_' + str(w)] = ta.trend.SMAIndicator(df0['Close'], window=w, fillna=True).sma_indicator()

                # SMA Crossover
                for w2 in windows:
                    if w > w2:
                        sma_s = ta.trend.SMAIndicator(df0['Close'], window=w, fillna=True).sma_indicator()
                        sma_f = ta.trend.SMAIndicator(df0['Close'], window=w2, fillna=True).sma_indicator()
                        df0['SMA_cross_f' + str(w2) + '_s' + str(w)] = sma_f - sma_s

                # EMA
                df0['EMA_' + str(w)] = ta.trend.EMAIndicator(df0['Close'], window=w, fillna=True).ema_indicator()

                # EMA Crossover
                for w2 in windows:
                    if w > w2:
                        ema_s = ta.trend.EMAIndicator(df0['Close'], window=w, fillna=True).ema_indicator()
                        ema_f = ta.trend.EMAIndicator(df0['Close'], window=w2, fillna=True).ema_indicator()
                        df0['SMA_cross_f' + str(w2) + '_s' + str(w)] = ema_f - ema_s


            ## WINDOW NOT REQUIRED
            # On Balance Volume Indicator (OBV)
            df0['OBV'] = ta.volume.OnBalanceVolumeIndicator(close=df0['Close'],volume=df0['Volume'], fillna=True).on_balance_volume()

            # Volume-Price Trend (VPT)
            df0['VPT'] = ta.volume.VolumePriceTrendIndicator(close=df0['Close'],volume=df0['Volume'], fillna=True).volume_price_trend()

            # Accumulation/Distribution Index Indicator (ADI)
            df0['ADI'] = ta.volume.AccDistIndexIndicator(high=df0['High'],low=df0['Low'],close=df0['Close'],volume=df0['Volume'], fillna=True).acc_dist_index()

        # Getting daily returns (pct and log) for 1,2,3 days
        return_days = [1,2,3,7,14]
        for day in return_days:
            df0[f'{day}_day_return'] = (df0['Close'] / df0['Close'].shift(day)) - 1
            df0[f'{day}_day_log_return'] = (np.log(df0['Close']) - np.log(df0['Close'].shift(day)) )* 100
        for day in return_days:
            df0[f'{day}_day_return'].fillna(0, inplace=True)
            df0[f'{day}_day_log_return'].fillna(0, inplace=True)

        all_tickers.append(df0)

    final = pd.concat(all_tickers)
    final = final.sort_values(by=['reportperiod','ticker'])

    return final

# %%
# ALL RAW DATA
print('Reading Raw Data...')
df = pd.read_pickle('../data/raw_data.pkl')
# Out:
# Reading Raw Data...

# %%
df.head()
# Out:
#       ticker dimension calendardate    datekey reportperiod lastupdated  \
# 57078    NKE       MRY   2011-12-31 2011-05-31   2011-05-31  2022-01-06
# 57077    NKE       MRY   2011-12-31 2011-05-31   2011-06-01  2022-01-06
# 57076    NKE       MRY   2011-12-31 2011-05-31   2011-06-02  2022-01-06
# 57075    NKE       MRY   2011-12-31 2011-05-31   2011-06-03  2022-01-06
# 57074    NKE       MRY   2011-12-31 2011-05-31   2011-06-06  2022-01-06
#
#            accoci        assets     assetsavg       assetsc  ...       taxexp  \
# 57078  95000000.0  1.499800e+10  1.449775e+10  1.129700e+10  ...  690000000.0
# 57077  95000000.0  1.499800e+10  1.449775e+10  1.129700e+10  ...  690000000.0
# 57076  95000000.0  1.499800e+10  1.449775e+10  1.129700e+10  ...  690000000.0
# 57075  95000000.0  1.499800e+10  1.449775e+10  1.129700e+10  ...  690000000.0
# 57074  95000000.0  1.499800e+10  1.449775e+10  1.129700e+10  ...  690000000.0
#
#        taxliabilities  tbvps  workingcapital       Open       High        Low  \
# 57078    1.038000e+09  7.543    7.339000e+09  21.209999  21.237499  20.955000
# 57077    1.038000e+09  7.543    7.339000e+09  21.084999  21.180000  20.520000
# 57076    1.038000e+09  7.543    7.339000e+09  20.467501  20.647499  20.264999
# 57075    1.038000e+09  7.543    7.339000e+09  20.127501  20.337500  20.055000
# 57074    1.038000e+09  7.543    7.339000e+09  20.092501  20.237499  19.934999
#
#            Close  Adj Close      Volume
# 57078  21.112499  18.571474   8879200.0
# 57077  20.537500  18.065693  10124800.0
# 57076  20.287500  17.913380  11829200.0
# 57075  20.090000  17.738981  11259200.0
# 57074  19.942499  17.608746   9092800.0
#
# [5 rows x 117 columns]

# %%
df.ticker.unique()
# Out:
# array(['NKE', nan, 'MSFT', 'PG', 'CSCO', 'AAPL', 'V', 'DIS', 'AXP', 'BA',
#        'CAT', 'CVX', 'DD', 'GE', 'GS', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO',
#        'MCD', 'MMM', 'MRK', 'PFE', 'TRV', 'TSLA', 'UNH', 'VZ', 'XOM',
#        'HD', 'WMT'], dtype=object)

# %%
 # Tickers chosen from clustering/sector selections
tickers = ['VZ', 'TSLA', 'INTC', 'CAT', 'JNJ', 'PFE', 'AAPL', 'MSFT']
df = df[df['ticker'].isin(tickers)]

# %%
 # Add technical features
print('Adding Technical Features...')
df = add_features(df)
# Out:
# Adding Technical Features...
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['STOCH_' + str(w)] = ta.momentum.StochasticOscillator(high=df0['High'],low=df0['Low'],close=df0['Close'], window=w, fillna=True).stoch()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['CMF_' + str(w)] = ta.volume.ChaikinMoneyFlowIndicator(high=df0['High'],low=df0['Low'],close=df0['Close'],volume=df0['Volume'], window=w, fillna=True).chaikin_money_flow()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['ICHI_conv_' + str(w3)+'_'+str(w2)+'_'+str(w)] = ichimoku.ichimoku_conversion_line()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:59: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['ICHI_base_' + str(w3)+'_'+str(w2)+'_'+str(w)] = ichimoku.ichimoku_base_line()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:60: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['ICHI_diff_' + str(w3)+'_'+str(w2)+'_'+str(w)] = df0['ICHI_conv_' + str(w3)+'_'+str(w2)+'_'+str(w)] - df0['ICHI_base_' + str(w3)+'_'+str(w2)+'_'+str(w)]
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['SMA_' + str(w)] = ta.trend.SMAIndicator(df0['Close'], window=w, fillna=True).sma_indicator()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:71: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['SMA_cross_f' + str(w2) + '_s' + str(w)] = sma_f - sma_s
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:74: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['EMA_' + str(w)] = ta.trend.EMAIndicator(df0['Close'], window=w, fillna=True).ema_indicator()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['RSI_' + str(w)] = ta.momentum.RSIIndicator(df0['Close'], window=w, fillna=True).rsi()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['MACD_f'+str(w2)+'_s'+str(w)] = ta.trend.MACD(df0['Close'], window_slow=w2, window_fast=w, fillna=True).macd_diff()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['BBands_' + str(w) + '_h_ind'] = bbands.bollinger_hband_indicator()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['BBands_' + str(w) + '_l_ind'] = bbands.bollinger_lband_indicator()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['BBands_' + str(w) + 'hband'] = bbands.bollinger_hband()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['BBands_' + str(w) + 'lband'] = bbands.bollinger_lband()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['ATR_' + str(w)] = ta.volatility.AverageTrueRange(high=df0['High'],low=df0['Low'],close=df0['Close'], window=w, fillna=True).average_true_range()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['DONCHAIN_' + str(w) + 'hband'] = d_channel.donchian_channel_hband()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['DONCHAIN_' + str(w) + 'lband'] = d_channel.donchian_channel_lband()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['KELTNER_' + str(w) + '_h_ind'] = k_channel.keltner_channel_hband_indicator()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['KELTNER_' + str(w) + '_l_ind'] = k_channel.keltner_channel_lband_indicator()
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0[f'{day}_day_return'] = (df0['Close'] / df0['Close'].shift(day)) - 1
# /var/folders/x4/n33clwmj1hx4s4k07_1ljf980000gn/T/ipykernel_52805/1779535800.py:98: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0[f'{day}_day_log_return'] = (np.log(df0['Close']) - np.log(df0['Close'].shift(day)) )* 100

# %%
df.iloc[:,113:].head()
# Out:
#              Low      Close  Adj Close      Volume  RSI_6  BBands_6_h_ind  \
# 54356  25.660000  26.000000  20.713482  52535400.0  100.0             0.0
# 54355  25.840000  26.020000  20.729418  52906200.0  100.0             0.0
# 54354  25.900000  26.030001  20.737379  37805300.0  100.0             0.0
# 54353  25.959999  26.330000  20.976383  48744200.0  100.0             0.0
# 54352  26.360001  26.770000  21.326921  51946500.0  100.0             0.0
#
#        BBands_6_l_ind  BBands_6hband  BBands_6lband  ATR_6  ...  1_day_return  \
# 54356             0.0      26.000000      26.000000    0.0  ...      0.000000
# 54355             0.0      26.030001      25.990000    0.0  ...      0.000769
# 54354             0.0      26.041612      25.991722    0.0  ...      0.000384
# 54353             0.0      26.367213      25.822787    0.0  ...      0.011525
# 54352             0.0      26.822352      25.637649    0.0  ...      0.016711
#
#        1_day_log_return  2_day_return  2_day_log_return  3_day_return  \
# 54356          0.000000      0.000000          0.000000      0.000000
# 54355          0.076895      0.000000          0.000000      0.000000
# 54354          0.038425      0.001154          0.115321      0.000000
# 54353          1.145923      0.011914          1.184348      0.012692
# 54352          1.657290      0.028429          2.803213      0.028824
#
#        3_day_log_return  7_day_return  7_day_log_return  14_day_return  \
# 54356          0.000000           0.0               0.0            0.0
# 54355          0.000000           0.0               0.0            0.0
# 54354          0.000000           0.0               0.0            0.0
# 54353          1.261243           0.0               0.0            0.0
# 54352          2.841638           0.0               0.0            0.0
#
#        14_day_log_return
# 54356                0.0
# 54355                0.0
# 54354                0.0
# 54353                0.0
# 54352                0.0
#
# [5 rows x 262 columns]

# %%
for ticker in df['ticker'].unique():
    df[df['ticker']==ticker].to_csv(f'../data/ticker_data/{ticker}_full_data.csv')
    print(f'{ticker} added to data')
print('Done')
# Out:
# MSFT added to data
# AAPL added to data
# CAT added to data
# INTC added to data
# JNJ added to data
# PFE added to data
# TSLA added to data
# VZ added to data
# Done
